# %% [markdown]
# #  Python Sets – Practice Questions

# %% [markdown]
# ### Q1
# Create a set from the list below and print only the unique values.
#
# ```python
# data = [10, 20, 20, 30, 40, 40]
# ```

# %%
# write your code here
data = [10, 20, 20, 30, 40, 40]
set1 = set(data)

print(set1)
# Out:
# {40, 10, 20, 30}

# %% [markdown]
# ### Q2
# What will be the output? Explain why.
#
# ```python
# s = {1, 2, 3, 3, 2}
# print(s)
# ```

# %%
# write your code here
s = {1, 2, 3, 3, 2}
print(s)

# The output will be {1,2,3} because set does not allow repeated values and automatically removes the repeated values
# Out:
# {1, 2, 3}

# %% [markdown]
# ### Q3
# Create an empty set and add numbers from 1 to 5 using a loop.

# %%
# write your code here
s1 = set()
s1.update('1','2','3','4','5')
print(s1)
# Out:
# {'1', '4', '2', '5', '3'}

# %% [markdown]
# ### Q4
# Why does this code give an error? Fix it.
#
# ```python
# s = {}
# s.add(10)
# ```

# %%
# write your code here
s = {}
s.add(10)
# This error occurs because the way 's' is defined as dictionary and not as set.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-643748537.py in <cell line: 0>()
#       1 # write your code here
#       2 s = {}
# ----> 3 s.add(10)
#
# AttributeError: 'dict' object has no attribute 'add'

# %%
# To solve this error
s = set()
s.add(10)
print(s)
# Out:
# {10}

# %% [markdown]
# ### Q5
# Given:
# ```python
# A = {2, 4, 6, 8}
# B = {4, 8, 12}
# ```
# Find Union, Intersection, A-B

# %%
# write your code here
A = {2, 4, 6, 8}
B = {4, 8, 12}
print('Union',A.union(B))
print("Intersection",A.intersection(B))
# Out:
# Union {2, 4, 6, 8, 12}
# Intersection {8, 4}

# %% [markdown]
# ### Q6
# Check whether 15 exists in the set {5, 10, 15, 20}.

# %%
# write your code here
s = {5, 10, 15, 20}
if 15 in s:
    print("15 exists in the set")
else:
  print("Not Found")
# Out:
# 15 exists in the set

# %% [markdown]
# ### Q7
# Remove element 30 safely from {10, 20, 30, 40}.

# %%
# write your code here
s = {10, 20, 30, 40}
s.discard(30)
print(s)
# Out:
# {40, 10, 20}

# %% [markdown]
# ### Q8
# Count unique elements in:
# ```python
# nums = [1, 2, 2, 3, 4, 4, 5]
# ```

# %%
# write your code here
nums = [1, 2, 2, 3, 4, 4, 5]
nums = set(nums)
print(len(nums))
# Out:
# 5

# %% [markdown]
# ### Q9
# What will be the output?
# ```python
# s = {10, 20, 30}
# s.add(20)
# print(len(s))
# ```

# %%
# write your code here
s = {10, 20, 30}
s.add(20)
print(len(s))

# The output is 3 as set doesnot allow repeated values so the output is 3
# Out:
# 3

# %% [markdown]
# ### Q10
# Can a set contain a list? Why?
# ```python
# s = {1, 2, [3, 4]}
# ```

# %%
# write your code here
s = {1, 2, [3, 4]}

# no a set cannot contain a list because list is mutable and unhasable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3969443797.py in <cell line: 0>()
#       1 # write your code here
# ----> 2 s = {1, 2, [3, 4]}
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# ### Q11
# Convert {100, 200, 300} into list and print first element.

# %%
# write your code here
l1 = [100, 200, 300]
ls = set(l1)
print(ls)
# Out:
# {200, 100, 300}

# %% [markdown]
# ### Q12
# Students in two classes:
# ```python
# class_A = {'Aman','Riya','Karan','Neha'}
# class_B = {'Neha','Simran','Aman'}
# ```

# %%
# write your code here
class_A = {'Aman','Riya','Karan','Neha'}
class_B = {'Neha','Simran','Aman'}
print("Union",class_A.union(class_B))
# Out:
# Union {'Karan', 'Aman', 'Simran', 'Riya', 'Neha'}

# %% [markdown]
# ### Q13
# Find unique characters in:
# ```python
# text = 'programming'
# ```

# %%
# write your code here
text = 'programming'
text = set(text)
print(text)
# Out:
# {'p', 'a', 'i', 'o', 'r', 'g', 'm', 'n'}

# %% [markdown]
# ### Q14
# Remove duplicate words from:
# ```python
# sentence = 'python is easy and python is powerful'
# ```

# %%
# write your code here
sentence = 'python is easy and python is powerful'
sentence = set(sentence.split())
print(sentence)
# Out:
# {'easy', 'is', 'python', 'and', 'powerful'}

# %% [markdown]
# ### Q15
# What is the output?
# ```python
# s = set('hello')
# print(s)
# ```

# %%
# write your code here
s = set('hello')
print(s)
# Out:
# {'h', 'l', 'e', 'o'}
